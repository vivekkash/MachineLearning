# %%
import pandas as pd

# %%
starwars = pd.read_csv("/Users/03000070/Downloads/StarWars.csv", encoding="latin - 1")

# %%
starwars
# Out:
#       RespondentID  \
# 0              NaN
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# 6     3.292719e+09
# 7     3.292685e+09
# 8     3.292664e+09
# 9     3.292654e+09
# 10    3.292640e+09
# 11    3.292638e+09
# 12    3.292635e+09
# 13    3.292609e+09
# 14    3.292597e+09
# 15    3.292587e+09
# 16    3.292583e+09
# 17    3.292581e+09
# 18    3.292573e+09
# 19    3.292565e+09
# 20    3.292562e+09
# 21    3.292522e+09
# 22    3.292521e+09
# 23    3.292512e+09
# 24    3.292483e+09
# 25    3.292465e+09
# 26    3.292448e+09
# 27    3.292420e+09
# 28    3.292384e+09
# 29    3.292380e+09
# ...            ...
# 1157  3.288426e+09
# 1158  3.288423e+09
# 1159  3.288423e+09
# 1160  3.288422e+09
# 1161  3.288421e+09
# 1162  3.288418e+09
# 1163  3.288418e+09
# 1164  3.288417e+09
# 1165  3.288415e+09
# 1166  3.288414e+09
# 1167  3.288413e+09
# 1168  3.288410e+09
# 1169  3.288410e+09
# 1170  3.288409e+09
# 1171  3.288403e+09
# ...

# %%
gm =  pd.read_csv("/Users/03000070/Downloads/gapminder.csv")

# %%
gm
# Out:
#      Unnamed: 0                   country  year    population      cont  \
# 0            11               Afghanistan  2007  3.188992e+07      Asia
# 1            23                   Albania  2007  3.600523e+06    Europe
# 2            35                   Algeria  2007  3.333322e+07    Africa
# 3            47                    Angola  2007  1.242048e+07    Africa
# 4            59                 Argentina  2007  4.030193e+07  Americas
# 5            71                 Australia  2007  2.043418e+07   Oceania
# 6            83                   Austria  2007  8.199783e+06    Europe
# 7            95                   Bahrain  2007  7.085730e+05      Asia
# 8           107                Bangladesh  2007  1.504483e+08      Asia
# 9           119                   Belgium  2007  1.039223e+07    Europe
# 10          131                     Benin  2007  8.078314e+06    Africa
# 11          143                   Bolivia  2007  9.119152e+06  Americas
# ...

# %%
gm.head()
# Out:
#    Unnamed: 0      country  year  population      cont  life_exp       gdp_cap
# 0          11  Afghanistan  2007  31889923.0      Asia    43.828    974.580338
# 1          23      Albania  2007   3600523.0    Europe    76.423   5937.029526
# 2          35      Algeria  2007  33333216.0    Africa    72.301   6223.367465
# 3          47       Angola  2007  12420476.0    Africa    42.731   4797.231267
# 4          59    Argentina  2007  40301927.0  Americas    75.320  12779.379640

# %%
gm.dtypes
# Out:
# Unnamed: 0      int64
# country        object
# year            int64
# population    float64
# cont           object
# life_exp      float64
# gdp_cap       float64
# dtype: object

# %%
gm = gm.drop(["Unnamed: 0"],1)

# %%
gm
# Out:
#                       country  year    population      cont  life_exp  \
# 0                 Afghanistan  2007  3.188992e+07      Asia    43.828
# 1                     Albania  2007  3.600523e+06    Europe    76.423
# 2                     Algeria  2007  3.333322e+07    Africa    72.301
# 3                      Angola  2007  1.242048e+07    Africa    42.731
# 4                   Argentina  2007  4.030193e+07  Americas    75.320
# 5                   Australia  2007  2.043418e+07   Oceania    81.235
# 6                     Austria  2007  8.199783e+06    Europe    79.829
# 7                     Bahrain  2007  7.085730e+05      Asia    75.635
# 8                  Bangladesh  2007  1.504483e+08      Asia    64.062
# 9                     Belgium  2007  1.039223e+07    Europe    79.441
# 10                      Benin  2007  8.078314e+06    Africa    56.728
# 11                    Bolivia  2007  9.119152e+06  Americas    65.554
# ...

# %%
gm["age"] = 2019 - gm["year"]

# %%
gm.head()
# Out:
#        country  year  population      cont  life_exp       gdp_cap  age
# 0  Afghanistan  2007  31889923.0      Asia    43.828    974.580338   12
# 1      Albania  2007   3600523.0    Europe    76.423   5937.029526   12
# 2      Algeria  2007  33333216.0    Africa    72.301   6223.367465   12
# 3       Angola  2007  12420476.0    Africa    42.731   4797.231267   12
# 4    Argentina  2007  40301927.0  Americas    75.320  12779.379640   12

# %%
gm["age"].value_counts()
# Out:
# 12    142
# Name: age, dtype: int64

# %%
gm = gm.drop(["year","age"],1)

# %%
gm.head()
# Out:
#        country  population      cont  life_exp       gdp_cap
# 0  Afghanistan  31889923.0      Asia    43.828    974.580338
# 1      Albania   3600523.0    Europe    76.423   5937.029526
# 2      Algeria  33333216.0    Africa    72.301   6223.367465
# 3       Angola  12420476.0    Africa    42.731   4797.231267
# 4    Argentina  40301927.0  Americas    75.320  12779.379640

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(gm["gdp_cap"],gm["life_exp"])
plt.show()

# %%
plt.scatter(gm["population"],gm["life_exp"])
plt.show()

# %%
#find the corelation between datasets
# corelation range varies from -1 to 1

gm["life_exp"].corr(gm["population"])
# Out:
# 0.047553115032827345

# %%
gm["life_exp"].corr(gm["gdp_cap"])
# Out:
# 0.6786623986777587

# %%
# bokeh can also be used for visualization/ plotting

# %%
plt.hist(gm["life_exp"])
# Out:
# (array([ 8.,  7., 10., 10., 10.,  8.,  5., 33., 23., 28.]),
#  array([39.613, 43.912, 48.211, 52.51 , 56.809, 61.108, 65.407, 69.706,
#         74.005, 78.304, 82.603]),
#  <a list of 10 Patch objects>)

# %%
# bins = 2 
plt.hist(gm["life_exp"],2)
# Out:
# (array([45., 97.]),
#  array([39.613, 61.108, 82.603]),
#  <a list of 2 Patch objects>)

# %%
starwars
# Out:
#       RespondentID  \
# 0              NaN
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# 6     3.292719e+09
# 7     3.292685e+09
# 8     3.292664e+09
# 9     3.292654e+09
# 10    3.292640e+09
# 11    3.292638e+09
# 12    3.292635e+09
# 13    3.292609e+09
# 14    3.292597e+09
# 15    3.292587e+09
# 16    3.292583e+09
# 17    3.292581e+09
# 18    3.292573e+09
# 19    3.292565e+09
# 20    3.292562e+09
# 21    3.292522e+09
# 22    3.292521e+09
# 23    3.292512e+09
# 24    3.292483e+09
# 25    3.292465e+09
# 26    3.292448e+09
# 27    3.292420e+09
# 28    3.292384e+09
# 29    3.292380e+09
# ...            ...
# 1157  3.288426e+09
# 1158  3.288423e+09
# 1159  3.288423e+09
# 1160  3.288422e+09
# 1161  3.288421e+09
# 1162  3.288418e+09
# 1163  3.288418e+09
# 1164  3.288417e+09
# 1165  3.288415e+09
# 1166  3.288414e+09
# 1167  3.288413e+09
# 1168  3.288410e+09
# 1169  3.288410e+09
# 1170  3.288409e+09
# 1171  3.288403e+09
# ...

# %%
starwars.dtypes
# Out:
# RespondentID                                                                                                                                     float64
# Have you seen any of the 6 films in the Star Wars franchise?                                                                                      object
# Do you consider yourself to be a fan of the Star Wars film franchise?                                                                             object
# Which of the following Star Wars films have you seen? Please select all that apply.                                                               object
# Unnamed: 4                                                                                                                                        object
# Unnamed: 5                                                                                                                                        object
# ...

# %%
header_1 = list(starwars)

# %%
list(starwars.iloc[:,:])
# Out:
# ['RespondentID',
#  'Have you seen any of the 6 films in the Star Wars franchise?',
#  'Do you consider yourself to be a fan of the Star Wars film franchise?',
#  'Which of the following Star Wars films have you seen? Please select all that apply.',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Which character shot first?',
# ...

# %%
headers
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
#
#                                     Unnamed: 4  \
# 0  Star Wars: Episode II  Attack of the Clones
#
#                                     Unnamed: 5  \
# 0  Star Wars: Episode III  Revenge of the Sith
#
#                           Unnamed: 6  \
# 0  Star Wars: Episode IV  A New Hope
#
#                                      Unnamed: 7  \
# 0  Star Wars: Episode V The Empire Strikes Back
#
#                                  Unnamed: 8  \
# 0  Star Wars: Episode VI Return of the Jedi
#
# ...

# %%
# merging the headers

header_1 = list(starwars)

# %%
header_1
# Out:
# ['RespondentID',
#  'Have you seen any of the 6 films in the Star Wars franchise?',
#  'Do you consider yourself to be a fan of the Star Wars film franchise?',
#  'Which of the following Star Wars films have you seen? Please select all that apply.',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Which character shot first?',
# ...

# %%
len(header_1)
# Out:
# 38

# %%
header_2 = starwars.iloc[0].tolist()

# %%
header_2
# Out:
# [nan,
#  'Response',
#  'Response',
#  'Star Wars: Episode I  The Phantom Menace',
#  'Star Wars: Episode II  Attack of the Clones',
#  'Star Wars: Episode III  Revenge of the Sith',
#  'Star Wars: Episode IV  A New Hope',
#  'Star Wars: Episode V The Empire Strikes Back',
#  'Star Wars: Episode VI Return of the Jedi',
#  'Star Wars: Episode I  The Phantom Menace',
#  'Star Wars: Episode II  Attack of the Clones',
#  'Star Wars: Episode III  Revenge of the Sith',
#  'Star Wars: Episode IV  A New Hope',
#  'Star Wars: Episode V The Empire Strikes Back',
#  'Star Wars: Episode VI Return of the Jedi',
#  'Han Solo',
#  'Luke Skywalker',
#  'Princess Leia Organa',
#  'Anakin Skywalker',
#  'Obi Wan Kenobi',
#  'Emperor Palpatine',
#  'Darth Vader',
#  'Lando Calrissian',
#  'Boba Fett',
#  'C-3P0',
#  'R2 D2',
#  'Jar Jar Binks',
#  'Padme Amidala',
#  'Yoda',
#  'Response',
#  'Response',
#  'Response',
#  'Response',
#  'Response',
#  'Response',
#  'Response',
#  'Response',
# ...

# %%
#assigning the header1 to header2

header_1[3:9] = header_2[3:9]

# %%
header_1
# Out:
# ['RespondentID',
#  'Have you seen any of the 6 films in the Star Wars franchise?',
#  'Do you consider yourself to be a fan of the Star Wars film franchise?',
#  'Star Wars: Episode I  The Phantom Menace',
#  'Star Wars: Episode II  Attack of the Clones',
#  'Star Wars: Episode III  Revenge of the Sith',
#  'Star Wars: Episode IV  A New Hope',
#  'Star Wars: Episode V The Empire Strikes Back',
#  'Star Wars: Episode VI Return of the Jedi',
#  'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
# ...

# %%
header_1[3:9] = [x + " Watched" for x in header_1[3:9]]

# %%
header_1
# Out:
# ['RespondentID',
#  'Have you seen any of the 6 films in the Star Wars franchise?',
#  'Do you consider yourself to be a fan of the Star Wars film franchise?',
#  'Star Wars: Episode I  The Phantom MenaceWatched Watched',
#  'Star Wars: Episode II  Attack of the ClonesWatched Watched',
#  'Star Wars: Episode III  Revenge of the SithWatched Watched',
#  'Star Wars: Episode IV  A New HopeWatched Watched',
#  'Star Wars: Episode V The Empire Strikes BackWatched Watched',
#  'Star Wars: Episode VI Return of the JediWatched Watched',
#  'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
# ...

# %%
header_1[9:15] = header_2[9:15]

# %%
header_1[9:15] = [x + " Rating" for x in header_1[9:15]]

# %%
header_1
# Out:
# ['RespondentID',
#  'Have you seen any of the 6 films in the Star Wars franchise?',
#  'Do you consider yourself to be a fan of the Star Wars film franchise?',
#  'Star Wars: Episode I  The Phantom Menace',
#  'Star Wars: Episode II  Attack of the Clones',
#  'Star Wars: Episode III  Revenge of the Sith',
#  'Star Wars: Episode IV  A New Hope',
#  'Star Wars: Episode V The Empire Strikes Back',
#  'Star Wars: Episode VI Return of the Jedi',
#  'Star Wars: Episode I  The Phantom Menace Rating',
#  'Star Wars: Episode II  Attack of the Clones Rating',
#  'Star Wars: Episode III  Revenge of the Sith Rating',
#  'Star Wars: Episode IV  A New Hope Rating',
#  'Star Wars: Episode V The Empire Strikes Back Rating',
#  'Star Wars: Episode VI Return of the Jedi Rating',
#  'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
# ...

# %%
header_1[15:29] = header_2[15:29]

# %%
header_1
# Out:
# ['RespondentID',
#  'Have you seen any of the 6 films in the Star Wars franchise?',
#  'Do you consider yourself to be a fan of the Star Wars film franchise?',
#  'Star Wars: Episode I  The Phantom Menace',
#  'Star Wars: Episode II  Attack of the Clones',
#  'Star Wars: Episode III  Revenge of the Sith',
#  'Star Wars: Episode IV  A New Hope',
#  'Star Wars: Episode V The Empire Strikes Back',
#  'Star Wars: Episode VI Return of the Jedi',
#  'Star Wars: Episode I  The Phantom Menace Rating',
#  'Star Wars: Episode II  Attack of the Clones Rating',
#  'Star Wars: Episode III  Revenge of the Sith Rating',
#  'Star Wars: Episode IV  A New Hope Rating',
#  'Star Wars: Episode V The Empire Strikes Back Rating',
#  'Star Wars: Episode VI Return of the Jedi Rating',
#  'Han Solo',
#  'Luke Skywalker',
#  'Princess Leia Organa',
#  'Anakin Skywalker',
#  'Obi Wan Kenobi',
#  'Emperor Palpatine',
#  'Darth Vader',
#  'Lando Calrissian',
#  'Boba Fett',
#  'C-3P0',
#  'R2 D2',
# ...

# %%
cleaned_df = pd.read_csv("/Users/03000070/Downloads/StarWars.csv", encoding="latin - 1" , skiprows = 2)

# %%
cleaned_df.columns = header_1

# %%
cleaned_df
# Out:
#       RespondentID  \
# 0       3292879538
# 1       3292765271
# 2       3292763116
# 3       3292731220
# 4       3292719380
# 5       3292684787
# 6       3292663732
# 7       3292654043
# 8       3292640424
# 9       3292637870
# 10      3292635062
# 11      3292609214
# 12      3292596911
# 13      3292587240
# 14      3292583038
# 15      3292580516
# 16      3292572872
# 17      3292565282
# 18      3292562297
# 19      3292522349
# 20      3292521066
# 21      3292511801
# 22      3292483200
# 23      3292465491
# 24      3292447974
# 25      3292420123
# 26      3292384040
# 27      3292380493
# 28      3292376985
# 29      3292366792
# ...            ...
# 1155    3288425859
# 1156    3288423088
# 1157    3288423045
# 1158    3288421819
# 1159    3288420798
# 1160    3288417782
# 1161    3288417641
# 1162    3288416959
# 1163    3288415166
# 1164    3288414025
# 1165    3288413441
# 1166    3288410348
# 1167    3288410073
# 1168    3288408698
# 1169    3288402717
# ...

# %%
# save to excel the cleaned data frames

# %%
writer = pd.ExcelWriter("/Users/03000070/Downloads/StarWars_headers_Cleaned.xlsx")
cleaned_df.to_excel(writer, "sheet1")
writer.save()

# %%
df = pd.read_excel("/Users/03000070/Downloads/StarWars_headers_Cleaned.xlsx")

# %%
df = df.drop(["Unnamed: 0"],1)

# %%
watched = df.iloc[:,3:9]

# %%
#turned the values into yes or no
watched[~watched.isnull()]="Yes"

# %%
watched = watched.fillna("No")

# %%
watched
# Out:
#      Star Wars: Episode I  The Phantom Menace  \
# 0                                          No
# 1                                         Yes
# 2                                         Yes
# 3                                         Yes
# 4                                         Yes
# 5                                         Yes
# 6                                         Yes
# 7                                         Yes
# 8                                          No
# 9                                          No
# 10                                         No
# 11                                        Yes
# 12                                        Yes
# 13                                        Yes
# 14                                        Yes
# 15                                         No
# 16                                        Yes
# 17                                        Yes
# 18                                        Yes
# ...

# %%
df = df.drop(list(watched),1)

# %%
df = pd.concat([df,watched],1)

# %%
df
# Out:
#       RespondentID  \
# 0       3292879538
# 1       3292765271
# 2       3292763116
# 3       3292731220
# 4       3292719380
# 5       3292684787
# 6       3292663732
# 7       3292654043
# 8       3292640424
# 9       3292637870
# 10      3292635062
# 11      3292609214
# 12      3292596911
# 13      3292587240
# 14      3292583038
# 15      3292580516
# 16      3292572872
# 17      3292565282
# 18      3292562297
# 19      3292522349
# 20      3292521066
# 21      3292511801
# 22      3292483200
# 23      3292465491
# 24      3292447974
# 25      3292420123
# 26      3292384040
# 27      3292380493
# 28      3292376985
# 29      3292366792
# ...            ...
# 1155    3288425859
# 1156    3288423088
# 1157    3288423045
# 1158    3288421819
# 1159    3288420798
# 1160    3288417782
# 1161    3288417641
# 1162    3288416959
# 1163    3288415166
# 1164    3288414025
# 1165    3288413441
# 1166    3288410348
# 1167    3288410073
# 1168    3288408698
# 1169    3288402717
# ...

# %%
df.iloc[:,3:9] = df.iloc[:,3:9].fillna(0)

# %%
df
# Out:
#       RespondentID  \
# 0       3292879538
# 1       3292765271
# 2       3292763116
# 3       3292731220
# 4       3292719380
# 5       3292684787
# 6       3292663732
# 7       3292654043
# 8       3292640424
# 9       3292637870
# 10      3292635062
# 11      3292609214
# 12      3292596911
# 13      3292587240
# 14      3292583038
# 15      3292580516
# 16      3292572872
# 17      3292565282
# 18      3292562297
# 19      3292522349
# 20      3292521066
# 21      3292511801
# 22      3292483200
# 23      3292465491
# 24      3292447974
# 25      3292420123
# 26      3292384040
# 27      3292380493
# 28      3292376985
# 29      3292366792
# ...            ...
# 1155    3288425859
# 1156    3288423088
# 1157    3288423045
# 1158    3288421819
# 1159    3288420798
# 1160    3288417782
# 1161    3288417641
# 1162    3288416959
# 1163    3288415166
# 1164    3288414025
# 1165    3288413441
# 1166    3288410348
# 1167    3288410073
# 1168    3288408698
# 1169    3288402717
# ...

# %%
df["Do you consider yourself to be a fan of the Star Wars film franchise?"] = df["Do you consider yourself to be a fan of the Star Wars film franchise?"].fillna("Maybe")

# %%
df["Do you consider yourself to be a fan of the Star Wars film franchise?"].value_counts()
# Out:
# Yes      551
# Maybe    350
# No       284
# Name: Do you consider yourself to be a fan of the Star Wars film franchise?, dtype: int64

# %%
writer = pd.ExcelWriter("/Users/03000070/Downloads/StarWars_headers_Cleaned_rating.xlsx")
df.to_excel(writer, "sheet1")
writer.save()

# %%
weather = pd.read_csv("/Users/03000070/Downloads/weather_2012.csv")

# %%
weather
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# 5     2012-01-01 05:00:00      -1.4                -3.3           87
# 6     2012-01-01 06:00:00      -1.5                -3.1           89
# 7     2012-01-01 07:00:00      -1.4                -3.6           85
# 8     2012-01-01 08:00:00      -1.4                -3.6           85
# 9     2012-01-01 09:00:00      -1.3                -3.1           88
# 10    2012-01-01 10:00:00      -1.0                -2.3           91
# 11    2012-01-01 11:00:00      -0.5                -2.1           89
# 12    2012-01-01 12:00:00      -0.2                -2.0           88
# ...

# %%
weather.index = weather["Date/Time"]

# %%
weather
# Out:
#                                Date/Time  Temp (C)  Dew Point Temp (C)  \
# Date/Time
# 2012-01-01 00:00:00  2012-01-01 00:00:00      -1.8                -3.9
# 2012-01-01 01:00:00  2012-01-01 01:00:00      -1.8                -3.7
# 2012-01-01 02:00:00  2012-01-01 02:00:00      -1.8                -3.4
# 2012-01-01 03:00:00  2012-01-01 03:00:00      -1.5                -3.2
# 2012-01-01 04:00:00  2012-01-01 04:00:00      -1.5                -3.3
# 2012-01-01 05:00:00  2012-01-01 05:00:00      -1.4                -3.3
# 2012-01-01 06:00:00  2012-01-01 06:00:00      -1.5                -3.1
# 2012-01-01 07:00:00  2012-01-01 07:00:00      -1.4                -3.6
# 2012-01-01 08:00:00  2012-01-01 08:00:00      -1.4                -3.6
# 2012-01-01 09:00:00  2012-01-01 09:00:00      -1.3                -3.1
# 2012-01-01 10:00:00  2012-01-01 10:00:00      -1.0                -2.3
# 2012-01-01 11:00:00  2012-01-01 11:00:00      -0.5                -2.1
# ...

# %%
weather = weather.drop(["Date/Time"],1)

# %%
weather.head()
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather
# Date/Time
# 2012-01-01 00:00:00                   Fog
# ...

# %%
# making index 

weather = pd.read_csv("/Users/03000070/Downloads/weather_2012.csv", index_col = "Date/Time", parse_dates = True)

# %%
weather
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
# 2012-01-01 05:00:00      -1.4                -3.3           87
# 2012-01-01 06:00:00      -1.5                -3.1           89
# 2012-01-01 07:00:00      -1.4                -3.6           85
# 2012-01-01 08:00:00      -1.4                -3.6           85
# 2012-01-01 09:00:00      -1.3                -3.1           88
# 2012-01-01 10:00:00      -1.0                -2.3           91
# 2012-01-01 11:00:00      -0.5                -2.1           89
# 2012-01-01 12:00:00      -0.2                -2.0           88
# 2012-01-01 13:00:00       0.2                -1.7           87
# ...

# %%
weather.dtypes
# Out:
# Temp (C)              float64
# Dew Point Temp (C)    float64
# Rel Hum (%)             int64
# Wind Spd (km/h)         int64
# Visibility (km)       float64
# Stn Press (kPa)       float64
# Weather                object
# dtype: object

# %%
weather.shape
# Out:
# (8784, 7)

# %%
monthly_data = weather.groupby(weather.index.month).mean()

# %%
monthly_data
# Out:
#             Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# Date/Time
# 1          -7.371505          -12.294758    68.383065        18.108871
# 2          -4.225000           -9.221695    68.956897        14.837644
# 3           3.121237           -3.488575    64.862903        14.514785
# 4           7.009306           -1.934583    56.150000        17.369444
# 5          16.237769            8.080780    61.760753        12.846774
# 6          20.134028           11.738056    60.643056        14.681944
# 7          22.790054           14.595430    62.017473        11.887097
# 8          22.279301           15.644758    67.943548        13.931452
# 9          16.484444           10.757917    71.165278        14.108333
# 10         10.954973            6.533468    75.731183        15.475806
# 11          0.931389           -4.179306    69.984722        13.973611
# 12         -3.306317           -6.129032    81.299731        17.614247
#
# ...

# %%
plt.plot(monthly_data["Temp (C)"])
plt.xlabel("Months")
plt.ylabel("Temps")
# Out:
# Text(0, 0.5, 'Temps')

# %%
# coverting to datetime longest way to do

# %%
autos = pd.read_csv("/Users/03000070/Downloads/Automobile_data.csv")

# %%
autos
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 ?         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 ?         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %%
autos.shape
# Out:
# (205, 26)

# %%
autos.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
autos.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
autos["price"].value_counts()
# Out:
# ?        4
# 8495     2
# 7898     2
# 7957     2
# 8845     2
# 6229     2
# 9279     2
# 6692     2
# 13499    2
# 16500    2
# 7609     2
# 7295     2
# 8921     2
# 5572     2
# 18150    2
# 7775     2
# 45400    1
# 7603     1
# 7499     1
# 18620    1
# 5348     1
# 40960    1
# 34028    1
# 30760    1
# 5118     1
# 18344    1
# 7053     1
# 24565    1
# 8249     1
# 13415    1
#         ..
# 13495    1
# 15040    1
# 12290    1
# 32250    1
# 11245    1
# 8449     1
# 15250    1
# 8949     1
# 37028    1
# 22470    1
# 8189     1
# 15985    1
# 6938     1
# 10345    1
# 6695     1
# 36880    1
# 12764    1
# 11199    1
# 21105    1
# 14489    1
# 11549    1
# 8238     1
# 13200    1
# 12940    1
# 6649     1
# 25552    1
# 7895     1
# 9549     1
# 16925    1
# 5195     1
# Name: price, Length: 187, dtype: int64

# %%
autos[autos["price"]!="?"]["price"].astype(float).mean()
# Out:
# 13207.129353233831

# %%
mean_price = autos[autos["price"]!="?"]["price"].astype(float).mean()

# %%
#pd. where
autos[autos["price"] =="?"] = autos[autos["price"] != "?"]["price"].astype(float).mean()

# %%
autos
# Out:
#         symboling normalized-losses         make fuel-type aspiration  \
# 0        3.000000                 ?  alfa-romero       gas        std
# 1        3.000000                 ?  alfa-romero       gas        std
# 2        1.000000                 ?  alfa-romero       gas        std
# 3        2.000000               164         audi       gas        std
# 4        2.000000               164         audi       gas        std
# 5        2.000000                 ?         audi       gas        std
# 6        1.000000               158         audi       gas        std
# 7        1.000000                 ?         audi       gas        std
# 8        1.000000               158         audi       gas      turbo
# 9    13207.129353           13207.1      13207.1   13207.1    13207.1
# 10       2.000000               192          bmw       gas        std
# 11       0.000000               192          bmw       gas        std
# ...

# %%
autos["price"].value_counts()
# Out:
# 13207.129353233831    4
# 16500                 2
# 9279                  2
# 7295                  2
# 7609                  2
# 13499                 2
# 6229                  2
# 8845                  2
# 8495                  2
# 7775                  2
# 7957                  2
# 7898                  2
# 18150                 2
# 5572                  2
# 6692                  2
# 8921                  2
# 34028                 1
# 7053                  1
# 24565                 1
# 7349                  1
# 7499                  1
# 18344                 1
# 18620                 1
# 5118                  1
# 45400                 1
# 30760                 1
# 7603                  1
# 7463                  1
# 5348                  1
# 40960                 1
#                      ..
# 6295                  1
# 13495                 1
# 15040                 1
# 12290                 1
# 11245                 1
# 15645                 1
# 8449                  1
# ...

# %%
def missing_values(column, symbol) : 
    mean_value = autos[autos[column]!=symbol][column].astype(float).mean()
    autos[autos[column] == symbol] = mean_value
    return autos

# %%
missing_values("normalized-losses","?")
# Out:
#         symboling normalized-losses        make fuel-type aspiration  \
# 0      433.550699           433.551     433.551   433.551    433.551
# 1      433.550699           433.551     433.551   433.551    433.551
# 2      433.550699           433.551     433.551   433.551    433.551
# 3        2.000000               164        audi       gas        std
# 4        2.000000               164        audi       gas        std
# 5      433.550699           433.551     433.551   433.551    433.551
# 6        1.000000               158        audi       gas        std
# 7      433.550699           433.551     433.551   433.551    433.551
# 8        1.000000               158        audi       gas      turbo
# 9    13207.129353           13207.1     13207.1   13207.1    13207.1
# 10       2.000000               192         bmw       gas        std
# 11       0.000000               192         bmw       gas        std
# 12       0.000000               188         bmw       gas        std
# ...

# %%
# alternative method to filter

def missingvalues(column,symbol):
       mean=autos[autos[column]!=symbol][column].astype(float).mean()
       autos[column]=autos[column].replace(symbol,mean).astype(float)
       return autos

#missingvalues("normalized-losses","?")

# %%
autos["normalized-losses"].value_counts()
# Out:
# 433.5506988865198     37
# 161                   11
# 91                     8
# 150                    7
# 134                    6
# 128                    6
# 104                    6
# 85                     5
# 74                     5
# 103                    5
# 94                     5
# 168                    5
# 102                    5
# 95                     5
# 65                     5
# 122                    4
# 13207.129353233831     4
# 93                     4
# 148                    4
# 106                    4
# 118                    4
# 137                    3
# 154                    3
# 101                    3
# 115                    3
# 83                     3
# 125                    3
# 89                     2
# 110                    2
# 188                    2
# 164                    2
# 108                    2
# 81                     2
# 87                     2
# 129                    2
# 158                    2
# 197                    2
# ...

# %%
missingvalues("horsepower","?")
# Out:
#         symboling normalized-losses        make fuel-type aspiration  \
# 0      433.550699           433.551     433.551   433.551    433.551
# 1      433.550699           433.551     433.551   433.551    433.551
# 2      433.550699           433.551     433.551   433.551    433.551
# 3        2.000000               164        audi       gas        std
# 4        2.000000               164        audi       gas        std
# 5      433.550699           433.551     433.551   433.551    433.551
# 6        1.000000               158        audi       gas        std
# 7      433.550699           433.551     433.551   433.551    433.551
# 8        1.000000               158        audi       gas      turbo
# 9    13207.129353           13207.1     13207.1   13207.1    13207.1
# 10       2.000000               192         bmw       gas        std
# 11       0.000000               192         bmw       gas        std
# 12       0.000000               188         bmw       gas        std
# ...

# %%
# !pip install word2number
# Out:
# ...
#   Stored in directory: /Users/03000070/Library/Caches/pip/wheels/46/2f/53/5f5c1d275492f2fce1cdab9a9bb12d49286dead829a4078e0e
# Successfully built word2number
# ...

# %%
from word2number import w2n

# %%
w2n.word_to_num('two')
# Out:
# 2

# %%
autos["num-of-doors"] = autos["num-of-doors"].str.replace("?","four")

autos["num-of-doors"].value_counts()
# Out:
# four    96
# two     68
# Name: num-of-doors, dtype: int64

# %%
doors = []

for x in range(autos.shape[0]):
       doors.append(w2n.word_to_num(autos["num-of-doors"].iloc[x]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-245-9d4eb0768a9e> in <module>
#       2
#       3 for x in range(autos.shape[0]):
# ----> 4        doors.append(w2n.word_to_num(autos["num-of-doors"].iloc[x]))
#
# /anaconda3/lib/python3.7/site-packages/word2number/w2n.py in word_to_num(number_sentence)
#     132 def word_to_num(number_sentence):
#     133     if type(number_sentence) is not str:
# --> 134         raise ValueError("Type of input is not string! Please enter a valid number word (eg. \'two million twenty three thousand and forty nine\')")
#     135
#     136     number_sentence = number_sentence.replace('-', ' ')
#
# ValueError: Type of input is not string! Please enter a valid number word (eg. 'two million twenty three thousand and forty nine')

# %%
autos["num-of-doors"] = pd.Series(doors)

# %%
autos.head()
# Out:
#     symboling normalized-losses     make fuel-type aspiration  num-of-doors  \
# 0  433.550699           433.551  433.551   433.551    433.551           NaN
# 1  433.550699           433.551  433.551   433.551    433.551           NaN
# 2  433.550699           433.551  433.551   433.551    433.551           NaN
# 3    2.000000               164     audi       gas        std           NaN
# 4    2.000000               164     audi       gas        std           NaN
#
#   body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0    433.551      433.551         433.551  433.550699  ...   433.550699
# 1    433.551      433.551         433.551  433.550699  ...   433.550699
# 2    433.551      433.551         433.551  433.550699  ...   433.550699
# 3      sedan          fwd           front   99.800000  ...   109.000000
# 4      sedan          4wd           front   99.400000  ...   136.000000
#
#    fuel-system     bore   stroke compression-ratio  horsepower  peak-rpm  \
# ...
